# %%
import treePlotter
reload(treePlotter)
# Out:
# <module 'treePlotter' from 'treePlotter.py'>

# %%
treePlotter.createPlot()

# %%
reload(treePlotter)
# Out:
# <module 'treePlotter' from 'treePlotter.py'>

# %%
treePlotter.retrieveTree(1)
# Out:
# {'no surfacing': {0: 'no',
#   1: {'flippers': {0: {'head': {0: 'no', 1: 'yes'}}, 1: 'no'}}}}

# %%
myTree = treePlotter.retrieveTree(0)

# %%
treePlotter.getNumLeafs(myTree)
# Out:
# 3

# %%
treePlotter.getTreeDepth(myTree)
# Out:
# 2

# %%
treePlotter.createPlot(myTree)

# %%
myTree['no surfacing'][3] = 'maybe'

# %%
myTree
# Out:
# {'no surfacing': {0: 'no', 1: {'flippers': {0: 'no', 1: 'yes'}}, 3: 'maybe'}}

# %%
treePlotter.createPlot(myTree)

# %%
import trees

# %%
myDat, labels = trees.createDataSet()

# %%
labels
# Out:
# ['no surfacing', 'flippers']

# %%
myTrees = treePlotter.retrieveTree(0)

# %%
myTrees
# Out:
# {'no surfacing': {0: 'no', 1: {'flippers': {0: 'no', 1: 'yes'}}}}

# %%
reload(trees)
# Out:
# <module 'trees' from 'trees.py'>

# %%
trees.classify(myTrees, labels, [1,0])
# Out:
# 'no'

# %%
trees.classify(myTree, labels, [1,1])
# Out:
# 'yes'

# %%
trees.storeTree(myTree, 'classifierStoreage.txt')

# %%
trees.grabTree('classifierStoreage.txt')
# Out:
# {'no surfacing': {0: 'no', 1: {'flippers': {0: 'no', 1: 'yes'}}}}

# %%
fr = open('lenses.txt')

# %%
lenses = [inst.strip().split('\t') for inst in fr.readlines()]

# %%
lenses
# Out:
# [['young', 'myope', 'no', 'reduced', 'no lenses'],
#  ['young', 'myope', 'no', 'normal', 'soft'],
#  ['young', 'myope', 'yes', 'reduced', 'no lenses'],
#  ['young', 'myope', 'yes', 'normal', 'hard'],
#  ['young', 'hyper', 'no', 'reduced', 'no lenses'],
#  ['young', 'hyper', 'no', 'normal', 'soft'],
#  ['young', 'hyper', 'yes', 'reduced', 'no lenses'],
#  ['young', 'hyper', 'yes', 'normal', 'hard'],
#  ['pre', 'myope', 'no', 'reduced', 'no lenses'],
#  ['pre', 'myope', 'no', 'normal', 'soft'],
#  ['pre', 'myope', 'yes', 'reduced', 'no lenses'],
#  ['pre', 'myope', 'yes', 'normal', 'hard'],
#  ['pre', 'hyper', 'no', 'reduced', 'no lenses'],
#  ['pre', 'hyper', 'no', 'normal', 'soft'],
#  ['pre', 'hyper', 'yes', 'reduced', 'no lenses'],
#  ['pre', 'hyper', 'yes', 'normal', 'no lenses'],
#  ['presbyopic', 'myope', 'no', 'reduced', 'no lenses'],
#  ['presbyopic', 'myope', 'no', 'normal', 'no lenses'],
#  ['presbyopic', 'myope', 'yes', 'reduced', 'no lenses'],
#  ['presbyopic', 'myope', 'yes', 'normal', 'hard'],
#  ['presbyopic', 'hyper', 'no', 'reduced', 'no lenses'],
#  ['presbyopic', 'hyper', 'no', 'normal', 'soft'],
#  ['presbyopic', 'hyper', 'yes', 'reduced', 'no lenses'],
#  ['presbyopic', 'hyper', 'yes', 'normal', 'no lenses']]

# %%
lensesLabels = ['age', 'prescript', 'astigmatic', 'tearRate']

# %%
lensesTree = trees.createTree(lenses, lensesLabels)

# %%
lensesTree
# Out:
# {'astigmatic': {'no': {'tearRate': {'normal': {'age': {'pre': 'soft',
#       'presbyopic': {'prescript': {'hyper': 'soft', 'myope': 'no lenses'}},
#       'young': 'soft'}},
#     'reduced': 'no lenses'}},
#   'yes': {'age': {'pre': {'prescript': {'hyper': 'no lenses',
#       'myope': {'tearRate': {'normal': 'hard', 'reduced': 'no lenses'}}}},
#     'presbyopic': {'prescript': {'hyper': 'no lenses',
#       'myope': {'tearRate': {'normal': 'hard', 'reduced': 'no lenses'}}}},
#     'young': {'tearRate': {'normal': 'hard', 'reduced': 'no lenses'}}}}}}

# %%
treePlotter.createPlot(lensesTree)
